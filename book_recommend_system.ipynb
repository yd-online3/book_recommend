# %% [markdown]
# 도서 추천 서비스

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('NL_BO_SPECIES_MASTER_NEW_202112.csv')
# Out:
# /var/folders/72/222764852597cbmznbjd4bsc0000gn/T/ipykernel_2596/3690055920.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('NL_BO_SPECIES_MASTER_NEW_202112.csv')

# %%
data.head()
# Out:
#    master_seq         isbn13  vol  \
# 0     6352228  9791156759270  NaN
# 1     6352229  9791168120877  NaN
# 2     6352230  9791168120839  NaN
# 3     6352231  9791168120846  NaN
# 4     6352232  9791168120747  NaN
#
#                                           title                     author  \
# 0  너에게 목소리를 보낼게 - &lt;달빛천사&gt; 성우 이용신의 첫 번째 에세이                  이용신 (지은이)
# 1         일기에도 거짓말을 쓰는 사람 - 99년생 시인의 자의식 과잉 에세이                  차도하 (지은이)
# 2                   본격 한중일 세계사 12 - 임오군란과 통킹 위기                굽시니스트 (지은이)
# 3          즉시 기분을 바꿔드립니다 - 신기하게 마음이 편해지는 응급 처방전  올리비아 레메스 (지은이), 김잔디 (옮긴이)
# 4                     오늘도 리추얼 : 음악, 나에게 선물하는 시간                  정혜윤 (지은이)
#
#   publisher  pub_date add_code    price  \
# 0       푸른숲       NaN      NaN  16000.0
# 1    위즈덤하우스       NaN      NaN  15800.0
# 2    위즈덤하우스       NaN      NaN  14800.0
# 3    위즈덤하우스       NaN      NaN  14000.0
# 4    위즈덤하우스       NaN      NaN  15000.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157118 entries, 0 to 157117
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   master_seq      157118 non-null  int64
#  1   isbn13          157118 non-null  int64
#  2   vol             39708 non-null   object
#  3   title           157118 non-null  object
#  4   author          157039 non-null  object
#  5   publisher       151577 non-null  object
#  6   pub_date        0 non-null       float64
#  7   add_code        129589 non-null  object
#  8   price           111394 non-null  float64
#  9   img_url         98337 non-null   object
#  10  description     84205 non-null   object
#  11  kdc_class_no    143057 non-null  float64
#  12  title_replace   148739 non-null  object
#  13  author_replace  149217 non-null  object
#  14  pub_date_2      103518 non-null  object
#  15  is_coll_aladin  154554 non-null  object
# ...

# %%
data.shape
# Out:
# (157118, 18)

# %%
data.isna().sum() / len(data) * 100 #결측비율 확인
# Out:
# master_seq          0.000000
# isbn13              0.000000
# vol                74.727275
# title               0.000000
# author              0.050281
# publisher           3.526649
# pub_date          100.000000
# add_code           17.521226
# price              29.101694
# img_url            37.412009
# description        46.406522
# kdc_class_no        8.949325
# title_replace       5.332934
# author_replace      5.028705
# pub_date_2         34.114487
# is_coll_aladin      1.631894
# is_coll_naver       1.631894
# isbn_origin        36.025153
# dtype: float64

# %%
# data.isnull().sum()
# Out:
# master_seq             0
# isbn13                 0
# vol               117410
# title                  0
# author                79
# publisher           5541
# pub_date          157118
# add_code           27529
# price              45724
# img_url            58781
# description        72913
# kdc_class_no       14061
# title_replace       8379
# author_replace      7901
# pub_date_2         53600
# is_coll_aladin      2564
# is_coll_naver       2564
# isbn_origin        56602
# dtype: int64

# %%
# data.columns
# Out:
# Index(['master_seq', 'isbn13', 'vol', 'title', 'author', 'publisher',
#        'pub_date', 'add_code', 'price', 'img_url', 'description',
#        'kdc_class_no', 'title_replace', 'author_replace', 'pub_date_2',
#        'is_coll_aladin', 'is_coll_naver', 'isbn_origin'],
#       dtype='object')

# %%
data['description'].isnull().any()
# Out:
# True

# %%
data['description'].unique()
# Out:
# array(['2004년 방영한 애니메이션 &lt;달빛천사&gt;에서 주인공 루나(풀문) 역을 맡으며 90년대생들에게 보석 같은 추억을 선물한 성우 이용신의 첫 번째 에세이. 수많은 작품의 주연을 맡으며 쉬지 않고 대중에게 행복을 전해온 성우 이용신의 발자취를 확인할 수 있다.',
#        '“그러니 나는 말하고 싶은 것을 말하겠다”「침착하게 사랑하기」 차도하 시인 첫 에세이새롭고 도발적인 작품성으로 문단의 기대주로 떠오른 차도하 시인의 첫 번째 산문집이 출간됐다. 혼자 보는 일기에도 거짓말을 쓸 수밖에 없었던 시인의 산문집 『일기에도 거짓말을 쓰는 사람』은 공교롭게도 보는...',
#        '한중일 관계의 결정적 분기점인 임오군란의 막전 막후를 다룬다. 러시아의 세력 확장을 경계한 청은 ‘친중·결일·연미’라는 계책을 앞세워 조선에 대한 통제를 강화하고, 이를 그냥 보아 넘길 수 없던 일본은 임오군란을 계기로 마수를 뻗치는데…. 정국 안정화와 근대 문물 도입을 향해 뛰어가는 조선의 앞에 놓인 거대한 장애물을 살펴본다.',
#        ...,
#        '갑작스레 세상에 나 혼자 남겨진 느낌이 들 때가 있다. 주위가 암전되고 덩그러니 남겨진 나는 스스로 무인도가 된다. 그렇게 나만의 테두리가 생겨나면, 자꾸만 나라는 존재는 보잘것없어 보인다. 깎여 버린 앙상한 나는, 심지어 나를 제외한 모두가 행복해 보이기까지 한다. 그러다 우연히 알게 된다. 이런 섬은 나만 있는 게 아니라는 걸.',
#        '오랫동안 하나의 목적을 이루기 위해 전념한 다양한 영웅들의 사례도 제시하고 있다. 이를 통해 세상을 바꾸는 힘의 중심에 헌신, 전념, 꾸준함이 있다는 것을 강조하고, 무한 탐색 모드가 만연한 세상에서 어떻게 자발적 전념하기를 추구할 것인지 구체적인 사례와 체계적인 정리를 통해 설명하고 있다.',
# ...

# %%
data1= data.copy()
data1 = data1['vol'].fillna('1')
data1.isna().any()
data1.unique()

data2 = data.copy()

# %%
# data['vol'].unique()
# Out:
# array([nan, '4', '2', ..., '1250', '1251', '553'], dtype=object)

# %%
# data1.isna().any()
# data1.unique()

# data2 = data.copy() #Data2로 복사해서 이용

# %%
data2['vol'] = data1

# %%
data2['vol'].unique()
# Out:
# array(['1', '4', '2', ..., '1250', '1251', '553'], dtype=object)

# %%
data2[data2['vol']=='1250']['title']
# Out:
# 156804    Oxford Reading Tree TreeTops Myths and Legends...
# Name: title, dtype: object

# %%
data2[data2['vol']=='중']
# Out:
#         master_seq         isbn13 vol  \
# 812        6353040  9788950743510   중
# 10138      6362428  9788932921556   중
# 10141      6362431  9788932921587   중
# 11755      2825839  9788984970588   중
# 18207      2417902  9788932311951   중
# 18520      2443783  9788935911608   중
# 19209      2822077  9788982736414   중
# 19214      2822080  9788982736445   중
# 21004       612839  9788974840129   중
# 21136       617403  9788932470535   중
# 21200       619820  9788976280268   중
# 22342       661209  9788979740011   중
# 22487      2651156  9788944702440   중
# 22670       675048  9788986110135   중
# 22715      2462498  9788986110289   중
# 22716       676407  9788986110265   중
# 22836       680877  9788986110302   중
# 23217       691497  9788978150309   중
# 30648      2655045  9788959800131   중
# 42047      2801359  9788963461557   중
# 46053      3359617  9788939808379   중
# 47365      1519339  9788947550154   중
# 48797      3359620  9788939808430   중
# ...

# %%
data[data['vol'].isna()]
# Out:
#         master_seq         isbn13  vol  \
# 0          6352228  9791156759270  NaN
# 1          6352229  9791168120877  NaN
# 2          6352230  9791168120839  NaN
# 3          6352231  9791168120846  NaN
# 4          6352232  9791168120747  NaN
# ...            ...            ...  ...
# 157113     6372497  9781191496148  NaN
# 157114     6372498  9781161755015  NaN
# 157115     6372499  9781197192907  NaN
# 157116     6372500  9781188005384  NaN
# 157117     6372501  9781191334426  NaN
#
#                                                     title  \
# 0            너에게 목소리를 보낼게 - &lt;달빛천사&gt; 성우 이용신의 첫 번째 에세이
# 1                   일기에도 거짓말을 쓰는 사람 - 99년생 시인의 자의식 과잉 에세이
# 2                             본격 한중일 세계사 12 - 임오군란과 통킹 위기
# 3                    즉시 기분을 바꿔드립니다 - 신기하게 마음이 편해지는 응급 처방전
# 4                               오늘도 리추얼 : 음악, 나에게 선물하는 시간
# ...                                                   ...
# 157113            설민석의 세계사 대모험 11 (영국 산업 혁명 편: 혁명에 맞선 자들)
# ...

# %%
data2[data2['publisher'].isna()] #크롤링 필요
# Out:
#         master_seq         isbn13 vol  \
# 54         6352282  9791186351420   4
# 56         6352284  9791186050286   1
# 57         6352285  9791186050149   1
# 58         6352286  9791186050651   1
# 59         6352287  9791186050095   1
# ...            ...            ...  ..
# 156916     6372298  9788949172699   1
# 156917     6372299  9788996048725   1
# 156919     6372301  9791136201510   3
# 156921     6372303  9791197508095   1
# 156927     6372309  9798997766963   1
#
#                                                     title  \
# 54                                              70년 만의 증언
# 56      (국립현대미술관 2015 미술관협력망 공동협력사업) 2015 빛 조각전 '문화예술의...
# 57                 (2015 민주인권평화전) 아빠의 청춘=Dad's Best Years
# 58                               (제17회 하정웅청년작가초대전) 빛 2017
# 59                                     광주 영아티스트전 QUESTION
# ...                                                   ...
# 156916                                           춤 추고 싶어요
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157118 entries, 0 to 157117
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   master_seq      157118 non-null  int64
#  1   isbn13          157118 non-null  int64
#  2   vol             157118 non-null  object
#  3   title           157118 non-null  object
#  4   author          157039 non-null  object
#  5   publisher       151577 non-null  object
#  6   pub_date        0 non-null       float64
#  7   add_code        129589 non-null  object
#  8   price           111394 non-null  float64
#  9   img_url         98337 non-null   object
#  10  description     84205 non-null   object
#  11  kdc_class_no    143057 non-null  float64
#  12  title_replace   148739 non-null  object
#  13  author_replace  149217 non-null  object
#  14  pub_date_2      103518 non-null  object
#  15  is_coll_aladin  154554 non-null  object
# ...

# %%
temp_author = data2['author'].unique()

# %% [markdown]
# temp_author.

# %%
data2['author'].value_counts()
# Out:
# 와룡강 지음         508
# [예지각]편집부 편저    377
# 사마달 지음         350
# 편저: 금융투자교육원    323
# 글/그림: 야설록      277
#               ...
# 박찬술 저            1
# 王统照 著            1
# 何青芳,费盛华 编著       1
# 이복규,김정훈 공저       1
# 신문범              1
# Name: author, Length: 94882, dtype: int64

# %%
temp_author2 = data2['author'].nunique()

temp_author2
# Out:
# 94882

# %%
data2[data2['author'].isna()] # 15여만 개 중 NaN값이 79개 정도로 미미하기 때문에 삭제 결정.
# Out:
#         master_seq         isbn13  vol  \
# 435        6352663  9798960215979  NaN
# 670        6352898  9788973343041  NaN
# 1304       6353537  9780865591448  NaN
# 1311       6353544  9781879636101  NaN
# 2042       6354295  9788907019516  NaN
# ...            ...            ...  ...
# 152335     6367713  9788984727168  NaN
# 152417     6367795  9788383757575    6
# 154266     6369645  9789070900786  NaN
# 155033     6370414  9791196380229  NaN
# 155204     6370585  9791190480499  NaN
#
#                                                     title author publisher  \
# 435                                                달의 빈자리    NaN       NaN
# 670                               (우등생을 위한)교과서 상식백과 : 3학년    NaN       NaN
# 1304         About place  =  : recent art of the Americas    NaN       NaN
# 1311    Intimate vistas  =  :  the poetic landscapes o...    NaN       NaN
# 2042                                            세계의 역사 탐구    NaN     금성출판사
# ...

# %%
data2['author'].isna() == False
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 157113    True
# 157114    True
# 157115    True
# 157116    True
# 157117    True
# Name: author, Length: 157118, dtype: bool

# %%
data2['author'].isna() == True
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 157113    False
# 157114    False
# 157115    False
# 157116    False
# 157117    False
# Name: author, Length: 157118, dtype: bool

# %%
data3 = data2.dropna(subset=['author'])

# %%
data3['author'].isna().any()
# Out:
# False

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157118 entries, 0 to 157117
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   master_seq      157118 non-null  int64
#  1   isbn13          157118 non-null  int64
#  2   vol             39708 non-null   object
#  3   title           157118 non-null  object
#  4   author          157039 non-null  object
#  5   publisher       151577 non-null  object
#  6   pub_date        0 non-null       float64
#  7   add_code        129589 non-null  object
#  8   price           111394 non-null  float64
#  9   img_url         98337 non-null   object
#  10  description     84205 non-null   object
#  11  kdc_class_no    143057 non-null  float64
#  12  title_replace   148739 non-null  object
#  13  author_replace  149217 non-null  object
#  14  pub_date_2      103518 non-null  object
#  15  is_coll_aladin  154554 non-null  object
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157039 entries, 0 to 157117
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   master_seq      157039 non-null  int64
#  1   isbn13          157039 non-null  int64
#  2   vol             39705 non-null   object
#  3   title           157039 non-null  object
#  4   author          157039 non-null  object
#  5   publisher       151572 non-null  object
#  6   pub_date        0 non-null       float64
#  7   add_code        129571 non-null  object
#  8   price           111394 non-null  float64
#  9   img_url         98337 non-null   object
#  10  description     84205 non-null   object
#  11  kdc_class_no    143040 non-null  float64
#  12  title_replace   148663 non-null  object
#  13  author_replace  149217 non-null  object
#  14  pub_date_2      103518 non-null  object
#  15  is_coll_aladin  154475 non-null  object
# ...

# %%
data3.head()
# Out:
#    master_seq         isbn13  vol  \
# 0     6352228  9791156759270  NaN
# 1     6352229  9791168120877  NaN
# 2     6352230  9791168120839  NaN
# 3     6352231  9791168120846  NaN
# 4     6352232  9791168120747  NaN
#
#                                           title                     author  \
# 0  너에게 목소리를 보낼게 - &lt;달빛천사&gt; 성우 이용신의 첫 번째 에세이                  이용신 (지은이)
# 1         일기에도 거짓말을 쓰는 사람 - 99년생 시인의 자의식 과잉 에세이                  차도하 (지은이)
# 2                   본격 한중일 세계사 12 - 임오군란과 통킹 위기                굽시니스트 (지은이)
# 3          즉시 기분을 바꿔드립니다 - 신기하게 마음이 편해지는 응급 처방전  올리비아 레메스 (지은이), 김잔디 (옮긴이)
# 4                     오늘도 리추얼 : 음악, 나에게 선물하는 시간                  정혜윤 (지은이)
#
#   publisher  pub_date add_code    price  \
# 0       푸른숲       NaN      NaN  16000.0
# 1    위즈덤하우스       NaN      NaN  15800.0
# 2    위즈덤하우스       NaN      NaN  14800.0
# 3    위즈덤하우스       NaN      NaN  14000.0
# 4    위즈덤하우스       NaN      NaN  15000.0
#
# ...

# %%
data4 = data3.drop(['pub_date'], axis=1)
data4.head()
# Out:
#    master_seq         isbn13  vol  \
# 0     6352228  9791156759270  NaN
# 1     6352229  9791168120877  NaN
# 2     6352230  9791168120839  NaN
# 3     6352231  9791168120846  NaN
# 4     6352232  9791168120747  NaN
#
#                                           title                     author  \
# 0  너에게 목소리를 보낼게 - &lt;달빛천사&gt; 성우 이용신의 첫 번째 에세이                  이용신 (지은이)
# 1         일기에도 거짓말을 쓰는 사람 - 99년생 시인의 자의식 과잉 에세이                  차도하 (지은이)
# 2                   본격 한중일 세계사 12 - 임오군란과 통킹 위기                굽시니스트 (지은이)
# 3          즉시 기분을 바꿔드립니다 - 신기하게 마음이 편해지는 응급 처방전  올리비아 레메스 (지은이), 김잔디 (옮긴이)
# 4                     오늘도 리추얼 : 음악, 나에게 선물하는 시간                  정혜윤 (지은이)
#
#   publisher add_code    price  \
# 0       푸른숲      NaN  16000.0
# 1    위즈덤하우스      NaN  15800.0
# 2    위즈덤하우스      NaN  14800.0
# 3    위즈덤하우스      NaN  14000.0
# 4    위즈덤하우스      NaN  15000.0
#
#                                              img_url  \
# 0  https://image.aladin.co.kr/product/28415/8/cov...
# ...

# %%
data4[data4['pub_date_2'].isna()] ## 크롤링 필요
# Out:
#         master_seq         isbn13  vol  \
# 54         6352282  9791186351420    4
# 56         6352284  9791186050286  NaN
# 57         6352285  9791186050149  NaN
# 58         6352286  9791186050651  NaN
# 59         6352287  9791186050095  NaN
# ...            ...            ...  ...
# 157112     6372496  9781197294120  NaN
# 157113     6372497  9781191496148  NaN
# 157115     6372499  9781197192907  NaN
# 157116     6372500  9781188005384  NaN
# 157117     6372501  9781191334426  NaN
#
#                                                     title  \
# 54                                              70년 만의 증언
# 56      (국립현대미술관 2015 미술관협력망 공동협력사업) 2015 빛 조각전 '문화예술의...
# 57                 (2015 민주인권평화전) 아빠의 청춘=Dad's Best Years
# 58                               (제17회 하정웅청년작가초대전) 빛 2017
# 59                                     광주 영아티스트전 QUESTION
# ...                                                   ...
# 157112                              대학&#x27;생&#x27;은 처음이라
# ...

# %%
data4['publisher'].isna().any()
# Out:
# True

# %%
data4[data4['add_code'].isna()]
# Out:
#         master_seq         isbn13  vol  \
# 0          6352228  9791156759270  NaN
# 1          6352229  9791168120877  NaN
# 2          6352230  9791168120839  NaN
# 3          6352231  9791168120846  NaN
# 4          6352232  9791168120747  NaN
# ...            ...            ...  ...
# 157113     6372497  9781191496148  NaN
# 157114     6372498  9781161755015  NaN
# 157115     6372499  9781197192907  NaN
# 157116     6372500  9781188005384  NaN
# 157117     6372501  9781191334426  NaN
#
#                                                     title  \
# 0            너에게 목소리를 보낼게 - &lt;달빛천사&gt; 성우 이용신의 첫 번째 에세이
# 1                   일기에도 거짓말을 쓰는 사람 - 99년생 시인의 자의식 과잉 에세이
# 2                             본격 한중일 세계사 12 - 임오군란과 통킹 위기
# 3                    즉시 기분을 바꿔드립니다 - 신기하게 마음이 편해지는 응급 처방전
# 4                               오늘도 리추얼 : 음악, 나에게 선물하는 시간
# ...                                                   ...
# 157113            설민석의 세계사 대모험 11 (영국 산업 혁명 편: 혁명에 맞선 자들)
# ...

# %%
data4['add_code'].unique()
# Out:
# array([nan, 93910.0, 3090.0, ..., '95830', '3090', '3098'], dtype=object)

# %%
data5 = data4.drop('price', axis=1)

# %%
data5.head()
# Out:
#    master_seq         isbn13  vol  \
# 0     6352228  9791156759270  NaN
# 1     6352229  9791168120877  NaN
# 2     6352230  9791168120839  NaN
# 3     6352231  9791168120846  NaN
# 4     6352232  9791168120747  NaN
#
#                                           title                     author  \
# 0  너에게 목소리를 보낼게 - &lt;달빛천사&gt; 성우 이용신의 첫 번째 에세이                  이용신 (지은이)
# 1         일기에도 거짓말을 쓰는 사람 - 99년생 시인의 자의식 과잉 에세이                  차도하 (지은이)
# 2                   본격 한중일 세계사 12 - 임오군란과 통킹 위기                굽시니스트 (지은이)
# 3          즉시 기분을 바꿔드립니다 - 신기하게 마음이 편해지는 응급 처방전  올리비아 레메스 (지은이), 김잔디 (옮긴이)
# 4                     오늘도 리추얼 : 음악, 나에게 선물하는 시간                  정혜윤 (지은이)
#
#   publisher add_code                                            img_url  \
# 0       푸른숲  93910.0  https://image.aladin.co.kr/product/28415/8/cov...
# 1    위즈덤하우스  93910.0  https://image.aladin.co.kr/product/28414/66/co...
# 2    위즈덤하우스  93910.0  https://image.aladin.co.kr/product/28414/47/co...
# ...

# %%
data6 = data5.drop('img_url', axis=1)
data6.head()
# Out:
#    master_seq         isbn13  vol  \
# 0     6352228  9791156759270  NaN
# 1     6352229  9791168120877  NaN
# 2     6352230  9791168120839  NaN
# 3     6352231  9791168120846  NaN
# 4     6352232  9791168120747  NaN
#
#                                           title                     author  \
# 0  너에게 목소리를 보낼게 - &lt;달빛천사&gt; 성우 이용신의 첫 번째 에세이                  이용신 (지은이)
# 1         일기에도 거짓말을 쓰는 사람 - 99년생 시인의 자의식 과잉 에세이                  차도하 (지은이)
# 2                   본격 한중일 세계사 12 - 임오군란과 통킹 위기                굽시니스트 (지은이)
# 3          즉시 기분을 바꿔드립니다 - 신기하게 마음이 편해지는 응급 처방전  올리비아 레메스 (지은이), 김잔디 (옮긴이)
# 4                     오늘도 리추얼 : 음악, 나에게 선물하는 시간                  정혜윤 (지은이)
#
#   publisher add_code                                        description  \
# 0       푸른숲  93910.0  2004년 방영한 애니메이션 &lt;달빛천사&gt;에서 주인공 루나(풀문) 역을 맡...
# 1    위즈덤하우스  93910.0  “그러니 나는 말하고 싶은 것을 말하겠다”「침착하게 사랑하기」 차도하 시인 첫 에세...
# 2    위즈덤하우스  93910.0  한중일 관계의 결정적 분기점인 임오군란의 막전 막후를 다룬다. 러시아의 세력 확장을...
# ...

# %%
data7 = data6.drop('description', axis=1)
data7.head()
# Out:
#    master_seq         isbn13  vol  \
# 0     6352228  9791156759270  NaN
# 1     6352229  9791168120877  NaN
# 2     6352230  9791168120839  NaN
# 3     6352231  9791168120846  NaN
# 4     6352232  9791168120747  NaN
#
#                                           title                     author  \
# 0  너에게 목소리를 보낼게 - &lt;달빛천사&gt; 성우 이용신의 첫 번째 에세이                  이용신 (지은이)
# 1         일기에도 거짓말을 쓰는 사람 - 99년생 시인의 자의식 과잉 에세이                  차도하 (지은이)
# 2                   본격 한중일 세계사 12 - 임오군란과 통킹 위기                굽시니스트 (지은이)
# 3          즉시 기분을 바꿔드립니다 - 신기하게 마음이 편해지는 응급 처방전  올리비아 레메스 (지은이), 김잔디 (옮긴이)
# 4                     오늘도 리추얼 : 음악, 나에게 선물하는 시간                  정혜윤 (지은이)
#
#   publisher add_code  kdc_class_no title_replace author_replace  pub_date_2  \
# 0       푸른숲  93910.0           NaN           NaN            NaN  2021-12-03
# 1    위즈덤하우스  93910.0           NaN           NaN            NaN  2021-12-06
# ...

# %%
data7[data7['kdc_class_no'].isna()]
# Out:
#         master_seq         isbn13  vol  \
# 0          6352228  9791156759270  NaN
# 1          6352229  9791168120877  NaN
# 2          6352230  9791168120839  NaN
# 3          6352231  9791168120846  NaN
# 4          6352232  9791168120747  NaN
# ...            ...            ...  ...
# 157113     6372497  9781191496148  NaN
# 157114     6372498  9781161755015  NaN
# 157115     6372499  9781197192907  NaN
# 157116     6372500  9781188005384  NaN
# 157117     6372501  9781191334426  NaN
#
#                                                     title  \
# 0            너에게 목소리를 보낼게 - &lt;달빛천사&gt; 성우 이용신의 첫 번째 에세이
# 1                   일기에도 거짓말을 쓰는 사람 - 99년생 시인의 자의식 과잉 에세이
# 2                             본격 한중일 세계사 12 - 임오군란과 통킹 위기
# 3                    즉시 기분을 바꿔드립니다 - 신기하게 마음이 편해지는 응급 처방전
# 4                               오늘도 리추얼 : 음악, 나에게 선물하는 시간
# ...                                                   ...
# 157113            설민석의 세계사 대모험 11 (영국 산업 혁명 편: 혁명에 맞선 자들)
# ...

# %%
data8 = data7.dropna(subset=['kdc_class_no'])
data8['kdc_class_no'].isna().any()
# Out:
# False

# %%
data8.head()
# Out:
#     master_seq         isbn13  vol  \
# 54     6352282  9791186351420    4
# 55     6352283  9791168150102  NaN
# 56     6352284  9791186050286  NaN
# 57     6352285  9791186050149  NaN
# 58     6352286  9791186050651  NaN
#
#                                                 title                  author  \
# 54                                          70년 만의 증언      한국전쟁전후민간인희생자 경남유족회
# 55                                   그 너머의 시 - 오하룡 시집               오하룡 (지은이)
# 56  (국립현대미술관 2015 미술관협력망 공동협력사업) 2015 빛 조각전 '문화예술의...               광주시립미술관 편
# 57             (2015 민주인권평화전) 아빠의 청춘=Dad's Best Years  광주시립미술관,5·18기념재단 [같이]편
# 58                           (제17회 하정웅청년작가초대전) 빛 2017               광주시립미술관 편
#
#    publisher add_code  kdc_class_no                           title_replace  \
# 54       NaN  93910.0         903.0                                 70년만의증언
# 55       황금알  93910.0         811.7                              그너머의시오하룡시집
# ...

# %%
data8[data8['title_replace'].isna()] ## 외국어는 자료가 부족함으로
# Out:
#         master_seq         isbn13  vol                                title  \
# 616        6352844  9784198946630  NaN                   たとえば風が〈新裝版〉 (德間文庫)
# 617        6352845  9784167908942  NaN                 こいしいたべもの (文春文庫) (文庫)
# 723        6352951  9788986111519   12                      (國譯)西溪先生集. 一~二卷
# 1096       6353329  9772799537005   26                                梁山文學.
# 1542       6353775  9788974791420  NaN                                 禪關策進
# ...            ...            ...  ...                                  ...
# 156509     6371890  9785001087786  NaN               Продавец воздуха:роман
# 156510     6371891  9789919505110  NaN                            Эрүүл бие
# 156511     6371892  9789997318206  NaN                              Идэмхий
# 156512     6371893  9786581280208  NaN        ကြွက်သေရင်းနှီး သူဌေးဖြစ်နည်း
# 156514     6371895  9786161836320  NaN  ชุดหนูอยากฟัง บ้านต้นไม้ในวันหิมะตก
#
# ...

# %%
# Out:
# array([nan, '70년만의증언', '그너머의시오하룡시집', ..., '과탑이알려주는대학생활한권으로끝내기어서와,대학은처음이지',
#        '중학영문법총정리한권으로끝내기ebs강사혼공쌤허준석의quot쉽고재미있게끝내는중학영문법quot',
#        '더빅윈이룰것인가,남길것인가'], dtype=object)

# %%
temp = data8[data8['title_replace'].isna()]['title'].unique()

# %%
temp = pd.DataFrame(temp)

# %%
temp.head(50)
# Out:
#                                                     0
# 0                                  たとえば風が〈新裝版〉 (德間文庫)
# 1                                こいしいたべもの (文春文庫) (文庫)
# 2                                     (國譯)西溪先生集. 一~二卷
# 3                                               梁山文學.
# 4                                                禪關策進
# 5                                                いちにち
# 6                                     小說 となりのトトロ(ジブリ)
# 7                                  Рассказы для детей
# 8                                              うつ消し漢方
# 9                     いつもの料理にかけるだけ おからパウダ-ダイエット (單行本)
# 10                                      (南海 望雲山) 望雲寺誌
# 11                                             先賢筆蹟集.
# 12                                              消失的名字
# 13                            おいで、フクマル (えほんひろば) (大型本)
# 14    努力する人は報われない:「一生懸命」の大きな落とし穴に氣づきなさい (單行本(ソフトカバ-))
# 15                                         ハリネズミと暮らす本
# ...

# %%
data9 = data8.dropna(subset=['title_replace'])

# %%
data9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136775 entries, 54 to 156921
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   master_seq      136775 non-null  int64
#  1   isbn13          136775 non-null  int64
#  2   vol             35725 non-null   object
#  3   title           136775 non-null  object
#  4   author          136775 non-null  object
#  5   publisher       132729 non-null  object
#  6   add_code        136775 non-null  object
#  7   kdc_class_no    136775 non-null  float64
#  8   title_replace   136775 non-null  object
#  9   author_replace  134880 non-null  object
#  10  pub_date_2      91766 non-null   object
#  11  is_coll_aladin  134942 non-null  object
#  12  is_coll_naver   134942 non-null  object
#  13  isbn_origin     93879 non-null   object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 15.7+ MB

# %%
data9[data9['author_replace'].isna()]
# Out:
#         master_seq         isbn13  vol  \
# 1302       6353535  9789627875024  NaN
# 1519       6353752  9788970060095  NaN
# 4519       6356782  9784860087524  NaN
# 4525       6356788  9786163782922  NaN
# 4526       6356789  9786164415829  NaN
# ...            ...            ...  ...
# 150424     6365791  9787514864410   10
# 151555     6366927  9787510473258  NaN
# 151562     6366934  9787521728514  NaN
# 153685     6369063  9789858410681  NaN
# 156502     6371883  9785000836774  NaN
#
#                                                     title  \
# 1302    求索的路上  = The unending path : Harold Wong paint...
# 1519                                           (실전)産業安全技師
# 4519               時短勉強術[다문화:일본]:「根性なし」「体力なし」「ラクしたい」人のための
# 4525                         อยู่ไหนเอ่ย... จีโน่[다문화:태국]
# 4526                                อาหารดีมีพลัง[다문화:태국]
# ...                                                   ...
# 150424                                     植物大战僵尸2漫画人体的奥秘
# ...

# %%
data10 = data9.dropna(subset=['author_replace'])

# %%
data10['author_replace'].isna().any()
# Out:
# False

# %%
data11 = data10.drop(['pub_date_2', 'is_coll_aladin', 'is_coll_naver'], axis=1)

# %%
data12 = data11.drop('isbn_origin', axis=1)

# %%
data13 = data12.drop('vol', axis=1)

# %%
data14 = data13.drop('publisher', axis=1)

# %%
data14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134880 entries, 54 to 156921
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   master_seq      134880 non-null  int64
#  1   isbn13          134880 non-null  int64
#  2   title           134880 non-null  object
#  3   author          134880 non-null  object
#  4   add_code        134880 non-null  object
#  5   kdc_class_no    134880 non-null  float64
#  6   title_replace   134880 non-null  object
#  7   author_replace  134880 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 9.3+ MB
